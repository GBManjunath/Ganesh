# %% [markdown]
# <a href="https://colab.research.google.com/github/GBManjunath/Ganesh/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.
# Probability Mass Function (PMF): The PMF is used for discrete random variables and gives the probability of a specific outcome occurring. It is defined only for discrete values and provides the likelihood that a random variable will take a particular value.
#
# Example: For a fair six-sided die, the PMF for each outcome (1, 2, 3, 4, 5, 6) is:
#
# �
# (
# �
# =
# �
# )
# =
# 1
# 6
#  for each
# �
# ∈
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# P(X=x)=
# 6
# 1
# ​
#   for each x∈{1,2,3,4,5,6}
# Each face has an equal probability of occurring.
#
# Probability Density Function (PDF): The PDF is used for continuous random variables and defines the likelihood of a random variable falling within a given range of values, rather than taking an exact value. The area under the curve of the PDF within a range represents the probability that the random variable lies within that range.
#
# Example: In a normal distribution with mean 0 and standard deviation 1, the PDF at any point
# �
# x is:
#
# �
# (
# �
# )
# =
# 1
# 2
# �
# exp
# ⁡
# (
# −
# �
# 2
# 2
# )
# f(x)=
# 2π
# ​
#
# 1
# ​
#  exp(−
# 2
# x
# 2
#
# ​
#  )
# This gives the density, and the total area under the curve is 1.
#
# Q2: What is Cumulative Distribution Function (CDF)? Explain with an example. Why CDF is used?
# Cumulative Distribution Function (CDF): The CDF is a function that gives the probability that a random variable is less than or equal to a particular value. It provides the cumulative probability up to a certain point. The CDF is defined for both discrete and continuous distributions.
#
# Example: For a normal distribution with mean 0 and standard deviation 1, the CDF at a value
# �
# x gives the probability that the random variable
# �
# X is less than or equal to
# �
# x. Mathematically:
#
# �
# (
# �
# )
# =
# �
# (
# �
# ≤
# �
# )
# F(x)=P(X≤x)
# For
# �
# =
# 1
# x=1, the CDF might be approximately 0.8413, meaning there’s an 84.13% chance that the variable is less than or equal to 1.
#
# Why is the CDF used? The CDF is useful for calculating the probability that a random variable falls within a specific range (i.e.,
# �
# (
# �
# ≤
# �
# ≤
# �
# )
# =
# �
# (
# �
# )
# −
# �
# (
# �
# )
# P(a≤X≤b)=F(b)−F(a)). It is used to find probabilities over intervals and to compute percentiles.
#
# Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.
# Examples of Normal Distribution Use:
#
# Heights of individuals: The distribution of heights in a large population often follows a normal distribution.
# Test scores: Scores on standardized tests like the SAT often follow a normal distribution.
# Measurement errors: Errors in measurements, such as the precision of a scale, often follow a normal distribution.
# Parameters and Shape: The normal distribution is characterized by two parameters:
#
# Mean (μ): This is the center of the distribution. It determines the location of the peak.
# Standard deviation (σ): This controls the spread of the distribution. A larger standard deviation results in a wider, flatter curve, while a smaller standard deviation results in a narrower, taller curve.
# Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution.
# The normal distribution is important because it describes many natural phenomena and is widely used in statistical analysis. It is the foundation for many statistical methods, including hypothesis testing and confidence intervals. The central limit theorem states that the sum (or average) of a large number of independent and identically distributed random variables approaches a normal distribution, making it a crucial tool in statistics.
#
# Examples:
# IQ scores: IQ scores are typically distributed normally with a mean of 100 and a standard deviation of 15.
# Blood pressure: In a large population, blood pressure measurements often follow a normal distribution.
# Stock prices: The returns of some financial assets can be modeled using a normal distribution.
# Q5: What is Bernoulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial Distribution?
# Bernoulli Distribution: The Bernoulli distribution is the simplest discrete probability distribution, representing a single trial with two possible outcomes: success (1) or failure (0). It is parameterized by the probability of success
# �
# p, and the probability of failure is
# 1
# −
# �
# 1−p.
#
# Example: A single coin flip, where:
#
# Success (1) = heads (with probability
# �
# =
# 0.5
# p=0.5)
# Failure (0) = tails (with probability
# 1
# −
# �
# =
# 0.5
# 1−p=0.5)
# Difference between Bernoulli and Binomial Distribution:
#
# A Bernoulli distribution is for a single trial, whereas a Binomial distribution models the number of successes in a fixed number of independent Bernoulli trials.
# Binomial distribution has two parameters:
# �
# n (number of trials) and
# �
# p (probability of success in each trial).
# Q6: Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally distributed, what is the probability that a randomly selected observation will be greater than 60? Use the appropriate formula and show your calculations.
# To find the probability that a randomly selected observation is greater than 60 in a normal distribution, we can use the z-score formula:
#
# �
# =
# �
# −
# �
# �
# z=
# σ
# x−μ
# ​
#
# Where:
#
# �
# =
# 60
# x=60 (the value we're interested in),
# �
# =
# 50
# μ=50 (mean),
# �
# =
# 10
# σ=10 (standard deviation).
# �
# =
# 60
# −
# 50
# 10
# =
# 1
# z=
# 10
# 60−50
# ​
#  =1
# Now, using the z-table or a standard normal distribution calculator, the probability corresponding to
# �
# =
# 1
# z=1 is approximately 0.8413. Since we want the probability of being greater than 60, we subtract this from 1:
#
# �
# (
# �
# >
# 60
# )
# =
# 1
# −
# 0.8413
# =
# 0.1587
# P(X>60)=1−0.8413=0.1587
# Thus, the probability that a randomly selected observation is greater than 60 is 0.1587, or 15.87%.
#
# Q7: Explain Uniform Distribution with an Example.
# The uniform distribution is a probability distribution in which all outcomes are equally likely. It is defined by two parameters: the minimum value
# �
# a and the maximum value
# �
# b.
#
# Example: Rolling a fair six-sided die. The outcome can be any of 1, 2, 3, 4, 5, or 6, and each outcome has an equal probability of occurring. The probability for each outcome is
# 1
# 6
# 6
# 1
# ​
#  .
#
# Q8: What is the z-score? State the importance of the z-score.
# Z-score: The z-score is a measure of how many standard deviations a data point is from the mean. It is calculated using the formula:
#
# �
# =
# �
# −
# �
# �
# z=
# σ
# x−μ
# ​
#
# Where:
#
# �
# x is the value,
# �
# μ is the mean,
# �
# σ is the standard deviation.
# Importance of the Z-score: The z-score allows for the comparison of data points from different distributions by standardizing them. It also helps identify outliers, as values with z-scores above 3 or below -3 are often considered unusual.
#
# Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.
# The Central Limit Theorem (CLT) states that the distribution of the sample mean will approach a normal distribution as the sample size increases, regardless of the original distribution of the population, provided that the samples are independent and identically distributed. This is true even if the underlying population distribution is not normal.
#
# Significance: The CLT is the foundation of many statistical procedures, as it allows for the use of normal distribution approximations in hypothesis testing, confidence intervals, and other statistical methods.
# Q10: State the assumptions of the Central Limit Theorem.
# The assumptions of the Central Limit Theorem are:
#
# Independence: The observations in the sample must be independent of each other.
# Identically distributed: Each sample must be drawn from the same distribution (identical distribution).
# Sample size: The sample size should be sufficiently large, typically
# �
# ≥
# 30
# n≥30 for the CLT to hold.
# Finite variance: The population must have a finite variance
