# %% [markdown]
# <a href="https://colab.research.google.com/github/GBManjunath/Ganesh/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Explain Class and Object with respect to Object-Oriented Programming. Give a suitable example.
# Class: A class is a blueprint or a template for creating objects (instances). It defines the properties (attributes) and behaviors (methods) that the objects created from the class will have. A class doesn't occupy memory until an object is created from it.
#
# Object: An object is an instance of a class. It is created based on the class blueprint and contains real values for the attributes defined in the class. An object can access the methods and attributes defined within its class.
#
# Example:
#
# python
# Copy code
# # Defining a class named 'Car'
# class Car:
#     def __init__(self, make, model, year):
#         self.make = make
#         self.model = model
#         self.year = year
#
#     def display_info(self):
#         print(f"{self.year} {self.make} {self.model}")
#
# # Creating objects of the class 'Car'
# car1 = Car("Toyota", "Corolla", 2020)
# car2 = Car("Honda", "Civic", 2021)
#
# # Accessing the method of the objects
# car1.display_info()  # Output: 2020 Toyota Corolla
# car2.display_info()  # Output: 2021 Honda Civic
# In this example, Car is the class, and car1 and car2 are objects created from the Car class.
#
# Q2. Name the four pillars of OOPs.
# The four pillars of Object-Oriented Programming (OOP) are:
#
# Encapsulation: Bundling data (attributes) and methods (functions) that operate on the data into a single unit, i.e., a class. It also restricts direct access to some of an object's components to ensure the object’s integrity.
#
# Abstraction: Hiding the complexity of the system and exposing only the essential details to the user. It allows focusing on high-level mechanisms without delving into the intricate workings of the class or method.
#
# Inheritance: The mechanism by which one class can inherit attributes and methods from another class, allowing for code reuse and extending functionality.
#
# Polymorphism: The ability to take on multiple forms. In OOP, polymorphism allows methods to be used in different ways depending on the object or class type. It supports method overriding and method overloading.
#
# Q3. Explain why the __init__() function is used. Give a suitable example.
# __init__() Function: The __init__() function is a special method in Python, known as a constructor, that is automatically called when a new object (instance) of a class is created. It is used to initialize the attributes of the class and set initial values for the object.
#
# Example:
#
# python
# Copy code
# class Dog:
#     def __init__(self, name, breed):
#         self.name = name  # Initialize the 'name' attribute
#         self.breed = breed  # Initialize the 'breed' attribute
#
#     def bark(self):
#         print(f"{self.name} is barking!")
#
# # Creating an object of the Dog class
# dog1 = Dog("Buddy", "Golden Retriever")
# dog1.bark()  # Output: Buddy is barking!
# In this example, the __init__() function initializes the name and breed attributes when a new Dog object is created.
#
# Q4. Why self is used in OOPs?
# self: In Python, self refers to the instance of the class. It is a way to access the attributes and methods of the class from within the class itself. self is used to represent the instance of the class in its methods, and it allows each object to keep track of its own attributes.
#
# It is not a keyword but a convention. You could technically use another name, but self is the widely accepted convention.
# self allows different objects of the same class to have different values for their attributes.
# Example:
#
# python
# Copy code
# class Person:
#     def __init__(self, name, age):
#         self.name = name  # 'self' allows each object to have its own attributes
#         self.age = age
#
#     def greet(self):
#         print(f"Hello, my name is {self.name} and I am {self.age} years old.")
#
# # Creating objects with different attributes
# person1 = Person("Alice", 30)
# person2 = Person("Bob", 25)
#
# person1.greet()  # Output: Hello, my name is Alice and I am 30 years old.
# person2.greet()  # Output: Hello, my name is Bob and I am 25 years old.
# In this example, self refers to the individual objects (person1, person2) and allows each object to store its own name and age.
#
# Q5. What is inheritance? Give an example for each type of inheritance.
# Inheritance: Inheritance is a mechanism in OOP that allows a class (called a child class or subclass) to inherit attributes and methods from another class (called a parent class or superclass). This enables code reuse and the creation of more specialized versions of a base class.
#
# Types of inheritance:
#
# Single Inheritance: A subclass inherits from a single parent class.
#
# python
# Copy code
# class Animal:
#     def speak(self):
#         print("Animal makes a sound.")
#
# class Dog(Animal):
#     def speak(self):
#         print("Dog barks.")
#
# dog = Dog()
# dog.speak()  # Output: Dog barks.
# Multiple Inheritance: A subclass inherits from more than one parent class.
#
# python
# Copy code
# class Animal:
#     def speak(self):
#         print("Animal makes a sound.")
#
# class Pet:
#     def play(self):
#         print("Pet is playing.")
#
# class Dog(Animal, Pet):
#     def speak(self):
#         print("Dog barks.")
#
# dog = Dog()
# dog.speak()  # Output: Dog barks.
# dog.play()   # Output: Pet is playing.
# Multilevel Inheritance: A subclass inherits from a parent class, which itself inherits from another class.
#
# python
# Copy code
# class Animal:
#     def speak(self):
#         print("Animal makes a sound.")
#
# class Mammal(Animal):
#     def walk(self):
#         print("Mammal walks on land.")
#
# class Dog(Mammal):
#     def speak(self):
#         print("Dog barks.")
#
# dog = Dog()
# dog.speak()  # Output: Dog barks.
# dog.walk()   # Output: Mammal walks on land.
# Hierarchical Inheritance: Multiple subclasses inherit from a single parent class.
#
# python
# Copy code
# class Animal:
#     def speak(self):
#         print("Animal makes a sound.")
#
# class Dog(Animal):
#     def speak(self):
#         print("Dog barks.")
#
# class Cat(Animal):
#     def speak(self):
#         print("Cat meows.")
#
# dog = Dog()
# cat = Cat()
# dog.speak()  # Output: Dog barks.
# cat.speak()  # Output: Cat meows.
# In all of these examples, inheritance allows the child classes to reuse or modify methods and attributes from the parent classes.
